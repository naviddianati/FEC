# %%
import pandas as pd

# %%
data = pd.read_csv('stats.txt',na_values = ['NONE'],sep=' ')

# %%
data
# Out:
#         id1       id2  verdict    p-value  a  c  e     n  o  s
# 0   3562805    541866        0 -29.913314  0  0  3     0  1  1
# 1   3562805   9571612        0 -29.913314  0  0  1     0  1  1
# 2   3562805   6473708        0 -29.913314  0  0  1     0  1  1
# 3   3562805   5736217        0 -29.913314  0  0  1     0  1  1
# 4   3562805   6453627        0 -29.913314  0  0  1     0  1  1
# 5   3562805   8917411        0 -29.913314  0  0  1     0  1  1
# 6   3562805   9726191        0 -29.913314  0  0  1     0  1  1
# 7   3562805   9430369        0 -29.913314  0  0  1     0  1  1
# 8   3562805  10211910        0 -29.913314  0  0  1     0  1  1
# 9   3562805   7953643        0 -29.913314  0  0  1     0  1  1
# 10  3562805   8122283        0 -29.913314  0  0  1     0  1  1
# 11  3562805   6439490        0 -29.913314  0  0  1     0  1  1
# 12  3562805    259789        0 -29.913314  0  0  1     0  1  1
# 13  3562805   3769607        0 -28.762058  0  0  1     0  1  1
# ...

# %%
shape(data.values)
data.values[:10,:]
# Out:
# array([[  5.61177000e+05,   5.61133000e+05,   0.00000000e+00,
#          -2.03689065e+01,              nan,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  5.61177000e+05,   5.61151000e+05,   0.00000000e+00,
#          -2.03689065e+01,              nan,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  5.61177000e+05,   9.74553000e+05,   0.00000000e+00,
#          -2.03689065e+01,              nan,   3.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  5.61177000e+05,   3.76280000e+06,   0.00000000e+00,
#                      nan,              nan,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  5.61177000e+05,   2.41833900e+06,   0.00000000e+00,
#                      nan,              nan,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   1.00000000e+00],
# ...
